# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: David Norman
#
# Vem du har presenterat för: Arina Godman och Robert Westman
#
# Datum då du presenterade: 24-05-08
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 1s 663ms/step
# Predicted: [('n04409515', 'tennis_ball', 0.9999969), ('n04039381', 'racket', 2.7497408e-06), ('n03942813', 'ping-pong_ball', 5.5179182e-08)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
img_path_1 = 'me.jpg'
img_path_2 = 'uggla.jpg'
img_path_3 = 'spindel.jpg'
img_path_4 = 'knut.jpg'
img_path_5 = 'lucky.jpg'
img_path_6 = 'doris.jpg'
img_path_7 = 'ekorrmeme.jpg'

img = image.load_img(img_path_7, target_size=(800, 1400)) #224, 224 orginal format
img
# Out:
# <PIL.Image.Image image mode=RGB size=1400x800>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (800, 1400, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 800, 1400, 3)

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 356ms/step
# Predicted: [('n02441942', 'weasel', 0.05224538), ('n02442845', 'mink', 0.022221424), ('n02363005', 'beaver', 0.014018595)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# Förtränade är ett kraftfullt koncept då det är utvalda modeller med hög säkerhet, dock kan vi se att de har problem med att prediktera bilder med multipla variabler i sig, (se bild 6 som är en katt som ligger i en korg på en stol) detta ger oss en prediktion på t.ex "cradle", "birdhouse" och annat. medans om vi kollar på bild 7 som är en bild på en ekorre som sträcker på sig så kommer modellen prediktera "weasel", "mink" och "fox squirrel" vilket är relativt korrekt.

# %% [markdown]
# ## Slutsats.

# %% [markdown]
# Förtränade modeller är bra och starka på (i detta fall) statiska och enkla bilder. i detta fallet skulle jag säga att bilderna som valdes var för svåra för modellen att prediktera rätt!
#
# Om vi ändrar upplösningen så ändras predikteringen, är detta relevant?
